# %%
# Mounting to google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Changing directory to Session 14 project folder
% cd /content/gdrive/MyDrive/TSAI-EVA-7.0/11_YOLO/
# Out:
# /content/gdrive/MyDrive/TSAI-EVA-7.0/11_YOLO

# %%
# ! git clone https://github.com/theschoolofai/YoloV3.git

# %%
% cd YoloV3/
# Out:
# /content/gdrive/MyDrive/TSAI-EVA-7.0/11_YOLO/YoloV3

# %% [markdown]
# # Small coco dataset

# %%
# ! python train.py --data data/smalcoco/smalcoco.data --batch 10 --cache --epochs 25 --nosave

# %% [markdown]
# # Custom data set

# %%
! python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 10 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=10, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2943 found, 131 missing, 38 empty, 0 duplicate, for 3112 images): 100% 3112/3112 [18:32<00:00,  2.80it/s]
# Caching images (1.7GB): 100% 3112/3112 [20:02<00:00,  2.59it/s]
# Reading image shapes: 100% 338/338 [02:02<00:00,  2.77it/s]
# ...

# %% [markdown]
# # Annotated detect.py

# %%
! python detect.py --conf-thres 0.1 --output data/predictions/annotated_test/ --source data/annotated_images/
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='data/predictions/annotated_test/', save_txt=False, source='data/annotated_images/', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/16 data/annotated_images/eva7_ln_b22.jpg: 320x512 2 bootss, Done. (0.036s)
# image 2/16 data/annotated_images/eva7_ln_b23.jpg: 256x512 4 bootss, Done. (0.038s)
# ...

# %% [markdown]
# # Video detect.py

# %%
! python detect.py --conf-thres 0.1 --output data/predictions/video/ --source data/video_images/
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='data/predictions/video/', save_txt=False, source='data/video_images/', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/990 data/video_images/image-001.jpg: 320x512 2 masks, Done. (0.036s)
# image 2/990 data/video_images/image-002.jpg: 320x512 2 masks, Done. (0.033s)
# ...
